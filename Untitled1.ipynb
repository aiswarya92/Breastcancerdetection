# %% [markdown]
# # Loading and Preprocessing

# %%
import json
import math
import os

import cv2
from PIL import Image
import numpy as np
from keras import layers
from tensorflow.keras.models import Sequential

from tensorflow.keras.layers import Dense, Flatten, Dropout, Activation

from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img

import tensorflow as tf

# %%
trainData = 'dataset/train'
testData = 'dataset/test'
dnnModel = 'dnn_model.h5'

# %%
import matplotlib.pyplot as plt

# %%
imgW = 50
imgH = 50
trainSamples = 500
testSamples = 5
epochs = 100
batchSize = 10

# %% [markdown]
# # Training & Evaluation

# %%
def createModel(input_shape):
    model = Sequential()
    
    model.add(Flatten(input_shape = input_shape))
    model.add(Dense(128))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(64))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1))
    model.add(Activation('tanh'))
    
    model.compile(optimizer = 'rmsprop', 
                  loss = 'CategoricalCrossentropy',
                  metrics = ['accuracy'])
    
    return model

# %%
def train_model():
        
    datagen = ImageDataGenerator(rescale=1./255)
    
    model = createModel((50,50,3))
    print(model)
    
    train_generator = datagen.flow_from_directory(
            trainData,
            target_size = (imgW, imgH),
            batch_size = batchSize,
            shuffle = False)
    
    test_generator = datagen.flow_from_directory(
            testData,
            target_size = (imgW, imgH),
            batch_size = batchSize,
            shuffle = False)
    
    model.fit_generator(
            train_generator,
            steps_per_epoch = trainSamples, 
            epochs = epochs,
            validation_data = test_generator,
            validation_steps = trainSamples
            )
    
    model.save_weights(dnnModel)

# %%
train_model()
# Out:
# <keras.engine.sequential.Sequential object at 0x0000021E0E025CA0>
# Found 6204 images belonging to 2 classes.
# Found 48 images belonging to 2 classes.
# Epoch 1/100
# <ipython-input-9-ef62ef1d82e2>:20: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(
# 500/500 [==============================] - ETA: 0s - loss: 1.1921e-07 - accuracy: 0.5000WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 500 batches). You may need to use the repeat() function when building your dataset.
# 500/500 [==============================] - 13s 24ms/step - loss: 1.1921e-07 - accuracy: 0.5000 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 2/100
# 500/500 [==============================] - 10s 20ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 3/100
# 500/500 [==============================] - 8s 16ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 4/100
# 500/500 [==============================] - 7s 15ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 5/100
# 500/500 [==============================] - 7s 15ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 6/100
# 500/500 [==============================] - 7s 14ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 7/100
# 500/500 [==============================] - 8s 16ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 8/100
# 500/500 [==============================] - 7s 13ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 9/100
# 500/500 [==============================] - 9s 17ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 10/100
# 500/500 [==============================] - 7s 14ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 11/100
# 500/500 [==============================] - 8s 16ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 12/100
# 500/500 [==============================] - 6s 13ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 13/100
# 500/500 [==============================] - 8s 16ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 14/100
# 500/500 [==============================] - 7s 13ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 15/100
# 500/500 [==============================] - 7s 15ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 16/100
# 500/500 [==============================] - 7s 14ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 17/100
# 500/500 [==============================] - ETA: 0s - loss: 1.1921e-07 - accuracy: 0.50 - 7s 14ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 18/100
# 500/500 [==============================] - 7s 15ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 19/100
# 500/500 [==============================] - 7s 14ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 20/100
# 500/500 [==============================] - 9s 18ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 21/100
# 500/500 [==============================] - 7s 14ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 22/100
# 500/500 [==============================] - 8s 17ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 23/100
# 500/500 [==============================] - 7s 15ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 24/100
# 500/500 [==============================] - 9s 18ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 25/100
# 500/500 [==============================] - 7s 13ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 26/100
# 500/500 [==============================] - 10s 19ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 27/100
# 500/500 [==============================] - 8s 15ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 28/100
# 500/500 [==============================] - 9s 17ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 29/100
# 500/500 [==============================] - 7s 15ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 30/100
# 500/500 [==============================] - 8s 16ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 31/100
# 500/500 [==============================] - 7s 13ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 32/100
# 500/500 [==============================] - 8s 17ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 33/100
# 500/500 [==============================] - 7s 14ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 34/100
# 500/500 [==============================] - 9s 17ms/step - loss: 1.1921e-07 - accuracy: 0.5000 1s
# Epoch 35/100
# 500/500 [==============================] - 6s 13ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 36/100
# 500/500 [==============================] - 9s 18ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 37/100
# 500/500 [==============================] - 7s 14ms/step - loss: 1.1921e-07 - accuracy: 0.5000 0s - loss: 1.1921e-07 -
# Epoch 38/100
# 500/500 [==============================] - 9s 18ms/step - loss: 1.1921e-07 - accuracy: 0.5000 0s - loss: 1.1921e-07 - accu
# Epoch 39/100
# 500/500 [==============================] - 7s 14ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 40/100
# 500/500 [==============================] - 9s 18ms/step - loss: 1.1921e-07 - accuracy: 0.5000 4s -
# Epoch 41/100
# 500/500 [==============================] - 7s 13ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 42/100
# 500/500 [==============================] - 8s 16ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 43/100
# 500/500 [==============================] - 6s 13ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 44/100
# 500/500 [==============================] - 9s 18ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 45/100
# 500/500 [==============================] - 7s 14ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 46/100
# 500/500 [==============================] - 8s 17ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 47/100
# 500/500 [==============================] - 7s 14ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 48/100
# 500/500 [==============================] - 9s 17ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 49/100
# 500/500 [==============================] - 7s 13ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 50/100
# 500/500 [==============================] - 8s 17ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 51/100
# 500/500 [==============================] - 7s 14ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 52/100
# 500/500 [==============================] - 8s 15ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 53/100
# 500/500 [==============================] - 7s 15ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 54/100
# 500/500 [==============================] - 8s 16ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 55/100
# 500/500 [==============================] - 8s 16ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 56/100
# 500/500 [==============================] - 8s 16ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 57/100
# 500/500 [==============================] - 7s 15ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 58/100
# 500/500 [==============================] - 7s 15ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 59/100
# 500/500 [==============================] - 7s 15ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 60/100
# 500/500 [==============================] - 7s 15ms/step - loss: 1.1921e-07 - accuracy: 0.5000 0s - los
# Epoch 61/100
# 500/500 [==============================] - 9s 17ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 62/100
# 500/500 [==============================] - 8s 16ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 63/100
# 500/500 [==============================] - 8s 16ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 64/100
# 500/500 [==============================] - 8s 16ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 65/100
# 500/500 [==============================] - 9s 17ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 66/100
# 500/500 [==============================] - 9s 18ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 67/100
# 500/500 [==============================] - 9s 18ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 68/100
# 500/500 [==============================] - 9s 18ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 69/100
# 500/500 [==============================] - 7s 14ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 70/100
# 500/500 [==============================] - ETA: 0s - loss: 1.1921e-07 - accuracy: 0.50 - 8s 16ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 71/100
# 500/500 [==============================] - 7s 13ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 72/100
# 500/500 [==============================] - 8s 15ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 73/100
# 500/500 [==============================] - 8s 17ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 74/100
# 500/500 [==============================] - 9s 18ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 75/100
# 500/500 [==============================] - 8s 15ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 76/100
# 500/500 [==============================] - 8s 16ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 77/100
# 500/500 [==============================] - 7s 14ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 78/100
# 500/500 [==============================] - 8s 16ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 79/100
# 500/500 [==============================] - 7s 14ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 80/100
# 500/500 [==============================] - 7s 15ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 81/100
# 500/500 [==============================] - 8s 15ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 82/100
# 500/500 [==============================] - 7s 14ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 83/100
# 500/500 [==============================] - 8s 15ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 84/100
# 500/500 [==============================] - 7s 14ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 85/100
# 500/500 [==============================] - 8s 16ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 86/100
# 500/500 [==============================] - 7s 14ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 87/100
# 500/500 [==============================] - 9s 17ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 88/100
# 500/500 [==============================] - 7s 13ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 89/100
# 500/500 [==============================] - 9s 17ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 90/100
# 500/500 [==============================] - 7s 14ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 91/100
# 500/500 [==============================] - 9s 17ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 92/100
# 500/500 [==============================] - 7s 13ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 93/100
# 500/500 [==============================] - 9s 18ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 94/100
# 500/500 [==============================] - 7s 13ms/step - loss: 1.1921e-07 - accuracy: 0.5000 0s - loss: 1.1921e-07
# Epoch 95/100
# 500/500 [==============================] - 9s 18ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 96/100
# 500/500 [==============================] - 7s 14ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 97/100
# 500/500 [==============================] - 8s 17ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 98/100
# 500/500 [==============================] - 7s 14ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 99/100
# 500/500 [==============================] - 8s 16ms/step - loss: 1.1921e-07 - accuracy: 0.5000
# Epoch 100/100
# 500/500 [==============================] - 7s 15ms/step - loss: 1.1921e-07 - accuracy: 0.5000

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=55)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

cm = confusion_matrix(np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1))

cm_plot_label =['benign', 'malignant']
plot_confusion_matrix(cm, cm_plot_label, title ='Confusion Metrix for Breast Cancer')

# %% [markdown]
# # ROC and AUC

# %%
from sklearn.metrics import roc_auc_score, auc
from sklearn.metrics import roc_curve
roc_log = roc_auc_score(np.argmax(Y_test, axis=1), np.argmax(Y_pred_tta, axis=1))
false_positive_rate, true_positive_rate, threshold = roc_curve(np.argmax(Y_test, axis=1), np.argmax(Y_pred_tta, axis=1))
area_under_curve = auc(false_positive_rate, true_positive_rate)

plt.plot([0, 1], [0, 1], 'r--')
plt.plot(false_positive_rate, true_positive_rate, label='AUC = {:.3f}'.format(area_under_curve))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()
#plt.savefig(ROC_PLOT_FILE, bbox_inches='tight')
plt.close()

# %%
i=0
prop_class=[]
mis_class=[]

for i in range(len(Y_test)):
    if(np.argmax(Y_test[i])==np.argmax(Y_pred_tta[i])):
        prop_class.append(i)
    if(len(prop_class)==8):
        break

i=0
for i in range(len(Y_test)):
    if(not np.argmax(Y_test[i])==np.argmax(Y_pred_tta[i])):
        mis_class.append(i)
    if(len(mis_class)==8):
        break

# # Display first 8 images of benign
w=60
h=40
fig=plt.figure(figsize=(18, 10))
columns = 4
rows = 2

def Transfername(namecode):
    if namecode==0:
        return "Benign"
    else:
        return "Malignant"
    
for i in range(len(prop_class)):
    ax = fig.add_subplot(rows, columns, i+1)
    ax.set_title("Predicted result:"+ Transfername(np.argmax(Y_pred_tta[prop_class[i]]))
                       +"\n"+"Actual result: "+ Transfername(np.argmax(Y_test[prop_class[i]])))
    plt.imshow(X_test[prop_class[i]], interpolation='nearest')
plt.show()
